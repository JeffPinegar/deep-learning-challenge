# %% [markdown]
# # Jeff Pinegar
# jeffPinegar1@gmail.com <br>
# 717-982-0516<br>
# ## Challenge 21 - Deep learning - Nonprofit Foundation Alphabet Soup <br>
#
# Due: March 6, 2023<br>
#
# ---
#
# <u>**Summary:**</u><br>
# The data prep for this file is very close to the class starter code.  The exception is the ASK_AMT.  The started code offered not insight into what to do with this value.  After multiple attempts to wrangle this column I elected to log scale the values in this column.
#
# <u>**AMT_ASK:**</u><br>
# * Logarithmic scaling
#
# <u>**Variables dropped from the model:**</u><br>
# * EIN
# * Name
# * STATUS
# * SPECIAL_CONSIDERATIONS
#
# <u>**Binning:**</u><br>
# * APPLICATION_TYPE
# * CLASSIFICATION
#
# <u>**Special Freatures:**</u><br>
# * The results are logged to a CSV file.  The number of neurons for each layer (up to 6) the and the activation function for each layer as well as the final accuracy and loss are recorded.
# * Box plot to show the results of the transformed AMT_ASK
# * Heatmap showing correlation of independent variables
# * Export of ETL data so that it could be used in future model testing.
#
# ---

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import csv
import pingouin as pg   # https://pingouin-stats.org/build/html/index.html

# %% [markdown]
# ---
# ## Preprocess the Data (Step 1)
#
# Using your knowledge of Pandas and scikit-learn’s `StandardScaler()`, you’ll need to preprocess the dataset. This step prepares you for Step 2, where you'll compile, train, and evaluate the neural network model.
#
# Using the information we have provided in the starter code, follow the instructions to complete the preprocessing steps.
#
# 1. Read in the charity_data.csv to a Pandas DataFrame, and be sure to identify the following in your dataset:
#     * What variable(s) are the target(s) for your model?
#     * What variable(s) are the feature(s) for your model? <br><br>
#
#
# 2. Drop the `EIN` and `NAME` columns.
#
# 3. Determine the number of unique values for each column.
#
# 4. For columns that have more than 10 unique values, determine the number of data points for each unique value.
#
# 5. Use the number of data points for each unique value to pick a cutoff point to bin "rare" categorical variables together in a new value, `Other`, and then check if the binning was successful.
#
# 6. Use `pd.get_dummies()` to encode categorical variables.

# %%
#  Import and read the charity_data.csv.
application_df = pd.read_csv("./Resources/charity_data_BigAsk.csv")
application_df.head()
# Out:
#          EIN                                             NAME  \
# 0  942854057                          IHC HEALTH SERVICES INC
# 1  990073480  TRUSTEES OF THE ESTATE OF BERNICE PAUAHI BISHOP
# 2  946174066                             STANFORD HEALTH CARE
# 3  741109620                    WILLIAM MARSH RICE UNIVERSITY
# 4  900779996              CHILDRENS HEALTHCARE OF ATLANTA INC
#
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0               T3       Independent          C1000     Heathcare
# 1               T3       Independent          C2000  Preservation
# 2               T3       Independent          C1200     Heathcare
# 3               T3       Independent          C2000  Preservation
# 4               T3  CompanySponsored          C1000  Preservation
#
#    ORGANIZATION  STATUS INCOME_AMT SPECIAL_CONSIDERATIONS     ASK_AMT  \
# 0         Trust       1       50M+                      N  8597806340
# 1  Co-operative       1       50M+                      N  8556638692
# 2         Trust       1       50M+                      N  5591584994
# 3         Trust       1       50M+                      N  4653011914
# 4         Trust       1       50M+                      N  3391919220
#
#    IS_SUCCESSFUL        Income  Big_Ask
# 0              1   60,000,000   Big Ask
# 1              0   60,000,000   Big Ask
# 2              0   60,000,000   Big Ask
# 3              0   60,000,000   Big Ask
# 4              1   60,000,000   Big Ask

# %%
application_df.shape
# Out:
# (34299, 14)

# %%
application_df = application_df.sample( frac = 0.5)
application_df.shape
# Out:
# (17150, 14)

# %%
# Drop duplicates if they exist (Do this before dropping Nane and EIN)
application_df.drop_duplicates(inplace=True)

# Drop records with na
application_df.dropna(how='any', inplace=True)

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
X = application_df.drop(['EIN', 'NAME', 'STATUS', 'SPECIAL_CONSIDERATIONS'], axis=1)

# %%
Xclean = X.copy(deep=True)
Xclean.shape
# Out:
# (17150, 10)

# %%
# Drop ASK_AMT > 1 billion
Xclean.drop(Xclean[Xclean['ASK_AMT'] > 1000000000].index, inplace=True)
Xclean.head()
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 30989               T3  CompanySponsored          C2000  Preservation
# 2627                T3       Independent          C2000  Preservation
# 11699               T3  CompanySponsored          C1200  Preservation
# 15412               T3       Independent          C1000  Preservation
# 11022               T3       Independent          C2000  Preservation
#
#       ORGANIZATION INCOME_AMT  ASK_AMT  IS_SUCCESSFUL       Income    Big_Ask
# 30989  Association          0     5000              0         -     Drop or 0
# 2627         Trust      1M-5M   350809              0   3,000,000      normal
# 11699  Association          0     5000              1         -     Drop or 0
# 15412        Trust          0     5000              1         -     Drop or 0
# 11022        Trust          0     5000              1         -     Drop or 0

# %%
# Drop outliers 
Xclean = X.copy(deep=True)

# Drop ASK_AMT > 1 billion
Xclean.drop(Xclean[Xclean['ASK_AMT'] > 1000000000].index, inplace=True)

# Drop Records with 0 income asking for > 99,999
Xclean.drop(Xclean[(Xclean['INCOME_AMT'] == '0') & (Xclean['ASK_AMT'] > 99999)].index, inplace=True)

# Drop Records with Big Ask
Xclean.drop(Xclean[Xclean['Big_Ask'] == 'Big Ask'].index, inplace=True)

X = Xclean.drop(['Big_Ask', 'Income'], axis=1)

X.shape
#X = Xclean.copy(deep=True)
# Out:
# (17107, 8)

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE
X.describe(include = 'all').round(3)
# Out:
#        APPLICATION_TYPE  AFFILIATION CLASSIFICATION      USE_CASE  \
# count             17107        17107          17107         17107
# unique               15            6             61             5
# top                  T3  Independent          C1000  Preservation
# freq              13542         9166           8636         14103
# mean                NaN          NaN            NaN           NaN
# std                 NaN          NaN            NaN           NaN
# min                 NaN          NaN            NaN           NaN
# 25%                 NaN          NaN            NaN           NaN
# 50%                 NaN          NaN            NaN           NaN
# 75%                 NaN          NaN            NaN           NaN
# max                 NaN          NaN            NaN           NaN
#
#        ORGANIZATION INCOME_AMT       ASK_AMT  IS_SUCCESSFUL
# count         17107      17107  1.710700e+04      17107.000
# unique            4          9           NaN            NaN
# top           Trust          0           NaN            NaN
# freq          11737      12143           NaN            NaN
# mean            NaN        NaN  1.409690e+06          0.534
# std             NaN        NaN  2.419723e+07          0.499
# min             NaN        NaN  5.000000e+03          0.000
# 25%             NaN        NaN  5.000000e+03          0.000
# 50%             NaN        NaN  5.000000e+03          1.000
# 75%             NaN        NaN  8.047500e+03          1.000
# max             NaN        NaN  9.881147e+08          1.000

# %% [markdown]
# ### Reduce APPLICATION_TYPE

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE
X['APPLICATION_TYPE'].value_counts()
# Out:
# T3     13542
# T4       756
# T6       605
# T5       557
# T19      531
# T8       366
# T7       342
# T10      277
# T9        73
# T13       31
# T12       15
# T2         8
# T25        2
# T15        1
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
Cutoff = 1000
a = X['APPLICATION_TYPE'].value_counts()
application_types_to_replace = a[a < Cutoff].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    X['APPLICATION_TYPE'] = X['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
X['APPLICATION_TYPE'].value_counts()
# Out:
# T3       13542
# Other     3565
# Name: APPLICATION_TYPE, dtype: int64

# %% [markdown]
# ### Reduce CLASSIFICATION

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
X['CLASSIFICATION'].value_counts()
# Out:
# C1000    8636
# C2000    3002
# C1200    2458
# C2100     956
# C3000     936
#          ...
# C1283       1
# C2400       1
# C2150       1
# C1900       1
# C4200       1
# Name: CLASSIFICATION, Length: 61, dtype: int64

# %%
# plot the Classifications to have a closser look at the distribution
b = X['CLASSIFICATION'].value_counts()

# leave off the top two values so the graph is more useful for the intended purpose (further lowering the cutoff)
c = b[b<6000]
c.plot(kind="bar", figsize=(15,5))
# Out:
# <AxesSubplot: >

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classCutoff = 1000
b = X['CLASSIFICATION'].value_counts()
classifications_to_replace = b[b < classCutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    X['CLASSIFICATION'] = X['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
X['CLASSIFICATION'].value_counts()
# Out:
# C1000    8636
# Other    3011
# C2000    3002
# C1200    2458
# Name: CLASSIFICATION, dtype: int64

# %% [markdown]
# ### Reduce USE_CASE

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
b = X['USE_CASE'].value_counts()
b
# Out:
# Preservation     14103
# ProductDev        2746
# CommunityServ      197
# Heathcare           60
# Other                1
# Name: USE_CASE, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classCutoff = 1000
b = X['USE_CASE'].value_counts()
classifications_to_replace = b[b < classCutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    X['USE_CASE'] = X['USE_CASE'].replace(cls,"Other")
    
# Check to make sure binning was successful
X['USE_CASE'].value_counts()
# Out:
# Preservation    14103
# ProductDev       2746
# Other             258
# Name: USE_CASE, dtype: int64

# %% [markdown]
# ### Reduce ORGANIZATION

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
b = X['ORGANIZATION'].value_counts()
b
# Out:
# Trust           11737
# Association      5115
# Co-operative      227
# Corporation        28
# Name: ORGANIZATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classCutoff = 1000
b = X['ORGANIZATION'].value_counts()
classifications_to_replace = b[b < classCutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    X['ORGANIZATION'] = X['ORGANIZATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
X['ORGANIZATION'].value_counts()
# Out:
# Trust          11737
# Association     5115
# Other            255
# Name: ORGANIZATION, dtype: int64

# %%
# Look at INCOME_AMT value counts for potential binning
b = X['INCOME_AMT'].value_counts()
b
# Out:
# 0                12143
# 25000-99999       1888
# 100000-499999     1703
# 1M-5M              473
# 1-9999             357
# 10000-24999        271
# 10M-50M            116
# 5M-10M              91
# 50M+                65
# Name: INCOME_AMT, dtype: int64

# %% [markdown]
# ### Reduce AFFILIATION

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
b = X['AFFILIATION'].value_counts()
b
# Out:
# Independent         9166
# CompanySponsored    7883
# Family/Parent         33
# National              14
# Regional               8
# Other                  3
# Name: AFFILIATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classCutoff = 1000
b = X['AFFILIATION'].value_counts()
classifications_to_replace = b[b < classCutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    X['AFFILIATION'] = X['AFFILIATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
X['AFFILIATION'].value_counts()
# Out:
# Independent         9166
# CompanySponsored    7883
# Other                 58
# Name: AFFILIATION, dtype: int64

# %% [markdown]
# ## Scale the ASK_AMT

# %%
# because for the very large range of this variable (5,000  to + 10 Billion) I am using a logrithmic transformation.
X['ASK_AMT'] = np.log(X['ASK_AMT'])

# %%
plt.rcParams["figure.figsize"] = [10, 5]
sns.boxplot( x=X['INCOME_AMT']
      , y=X['ASK_AMT']
      , order = ('0', '1-9999', '10000-24999', '25000-99999', '100000-499999', '1M-5M', '5M-10M', '10M-50M', '50M+'))
# plt.ylim(0, 20000000)
plt.show()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
X_dummies = pd.get_dummies(X)
print(X_dummies.columns)
X_dummies
# Out:
# Index(['ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_Other',
#        'APPLICATION_TYPE_T3', 'AFFILIATION_CompanySponsored',
#        'AFFILIATION_Independent', 'AFFILIATION_Other', 'CLASSIFICATION_C1000',
#        'CLASSIFICATION_C1200', 'CLASSIFICATION_C2000', 'CLASSIFICATION_Other',
#        'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Other', 'ORGANIZATION_Trust',
#        'INCOME_AMT_0', 'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
#        'INCOME_AMT_100000-499999', 'INCOME_AMT_10M-50M', 'INCOME_AMT_1M-5M',
#        'INCOME_AMT_25000-99999', 'INCOME_AMT_50M+', 'INCOME_AMT_5M-10M'],
#       dtype='object')
#          ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T3  \
# 30989   8.517193              0                       0                    1
# 2627   12.767997              0                       0                    1
# 11699   8.517193              1                       0                    1
# 15412   8.517193              1                       0                    1
# 11022   8.517193              1                       0                    1
# ...          ...            ...                     ...                  ...
# 21427   8.517193              1                       0                    1
# 2268   13.083024              1                       0                    1
# 4954   11.305138              1                       0                    1
# 23198   8.517193              1                       0                    1
# 25691   8.517193              0                       0                    1
#
#        AFFILIATION_CompanySponsored  AFFILIATION_Independent  \
# 30989                             1                        0
# 2627                              0                        1
# 11699                             1                        0
# 15412                             0                        1
# 11022                             0                        1
# ...                             ...                      ...
# 21427                             0                        1
# 2268                              0                        1
# 4954                              1                        0
# 23198                             1                        0
# 25691                             1                        0
#
#        AFFILIATION_Other  CLASSIFICATION_C1000  CLASSIFICATION_C1200  \
# 30989                  0                     0                     0
# 2627                   0                     0                     0
# 11699                  0                     0                     1
# 15412                  0                     1                     0
# 11022                  0                     0                     0
# ...                  ...                   ...                   ...
# 21427                  0                     1                     0
# 2268                   0                     1                     0
# 4954                   0                     0                     0
# 23198                  0                     0                     0
# 25691                  0                     0                     1
#
#        CLASSIFICATION_C2000  ...  ORGANIZATION_Trust  INCOME_AMT_0  \
# 30989                     1  ...                   0             1
# 2627                      1  ...                   1             0
# 11699                     0  ...                   0             1
# 15412                     0  ...                   1             1
# 11022                     1  ...                   1             1
# ...                     ...  ...                 ...           ...
# 21427                     0  ...                   1             1
# 2268                      0  ...                   0             0
# 4954                      0  ...                   1             0
# 23198                     0  ...                   1             1
# 25691                     0  ...                   0             1
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 30989                  0                       0                         0
# 2627                   0                       0                         0
# 11699                  0                       0                         0
# 15412                  0                       0                         0
# 11022                  0                       0                         0
# ...                  ...                     ...                       ...
# 21427                  0                       0                         0
# 2268                   0                       0                         1
# 4954                   0                       0                         1
# 23198                  0                       0                         0
# 25691                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 30989                   0                 0                       0
# 2627                    0                 1                       0
# 11699                   0                 0                       0
# 15412                   0                 0                       0
# 11022                   0                 0                       0
# ...                   ...               ...                     ...
# 21427                   0                 0                       0
# 2268                    0                 0                       0
# 4954                    0                 0                       0
# 23198                   0                 0                       0
# 25691                   0                 0                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M
# 30989                0                  0
# 2627                 0                  0
# 11699                0                  0
# 15412                0                  0
# 11022                0                  0
# ...                ...                ...
# 21427                0                  0
# 2268                 0                  0
# 4954                 0                  0
# 23198                0                  0
# 25691                0                  0
#
# [17107 rows x 26 columns]

# %%
X_dummies.describe(include = 'all').round(3)
# Out:
#          ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  APPLICATION_TYPE_T3  \
# count  17107.000      17107.000               17107.000            17107.000
# mean       9.401          0.534                   0.208                0.792
# std        1.836          0.499                   0.406                0.406
# min        8.517          0.000                   0.000                0.000
# 25%        8.517          0.000                   0.000                1.000
# 50%        8.517          1.000                   0.000                1.000
# 75%        8.993          1.000                   0.000                1.000
# max       20.711          1.000                   1.000                1.000
#
#        AFFILIATION_CompanySponsored  AFFILIATION_Independent  \
# count                     17107.000                17107.000
# mean                          0.461                    0.536
# std                           0.498                    0.499
# min                           0.000                    0.000
# 25%                           0.000                    0.000
# 50%                           0.000                    1.000
# 75%                           1.000                    1.000
# max                           1.000                    1.000
#
#        AFFILIATION_Other  CLASSIFICATION_C1000  CLASSIFICATION_C1200  \
# count          17107.000             17107.000             17107.000
# mean               0.003                 0.505                 0.144
# std                0.058                 0.500                 0.351
# min                0.000                 0.000                 0.000
# 25%                0.000                 0.000                 0.000
# 50%                0.000                 1.000                 0.000
# 75%                0.000                 1.000                 0.000
# max                1.000                 1.000                 1.000
#
#        CLASSIFICATION_C2000  ...  ORGANIZATION_Trust  INCOME_AMT_0  \
# count             17107.000  ...           17107.000     17107.000
# mean                  0.175  ...               0.686         0.710
# std                   0.380  ...               0.464         0.454
# min                   0.000  ...               0.000         0.000
# 25%                   0.000  ...               0.000         0.000
# 50%                   0.000  ...               1.000         1.000
# 75%                   0.000  ...               1.000         1.000
# max                   1.000  ...               1.000         1.000
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# count          17107.000               17107.000                 17107.000
# mean               0.021                   0.016                     0.100
# std                0.143                   0.125                     0.299
# min                0.000                   0.000                     0.000
# 25%                0.000                   0.000                     0.000
# 50%                0.000                   0.000                     0.000
# 75%                0.000                   0.000                     0.000
# max                1.000                   1.000                     1.000
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# count           17107.000         17107.000               17107.000
# mean                0.007             0.028                   0.110
# std                 0.082             0.164                   0.313
# min                 0.000             0.000                   0.000
# 25%                 0.000             0.000                   0.000
# 50%                 0.000             0.000                   0.000
# 75%                 0.000             0.000                   0.000
# max                 1.000             1.000                   1.000
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M
# count        17107.000          17107.000
# mean             0.004              0.005
# std              0.062              0.073
# min              0.000              0.000
# 25%              0.000              0.000
# 50%              0.000              0.000
# 75%              0.000              0.000
# max              1.000              1.000
#
# [8 rows x 26 columns]

# %%
# looking to see if there are any variable that are highly correlated that may be preventing a more accurate model 
plt.figure(figsize=(10,7))
c= X_dummies.corr()
sns.heatmap(c)

# The correlation heat map below indicates the variables are not well separated.
# Out:
# <AxesSubplot: >

# %% [markdown]
# <u>**Save CVS**</u><br>
# Save the dummy encoded data to CSV so that it can imported into other Python programs for Model fitting and testing

# %%
# Save the dummy encoded data to CSV so that it can imported into other Python programs for Model fitting and testing
X_dummies.to_csv('clean_data_Reduced_log_dummies.csv', index=False, header=True)

# %% [markdown]
# Continue processing this file

# %%
# Seperate out the dependent and independen variables
# Split our preprocessed data into our features and target arrays

# this is the target
y = X_dummies["IS_SUCCESSFUL"].values

# Drop y out of the dataframe to get the independent variables
# this is the feature list
X = X_dummies.drop("IS_SUCCESSFUL", axis=1)
independent_variables = X.columns
X.head()
# Out:
#          ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T3  \
# 30989   8.517193                       0                    1
# 2627   12.767997                       0                    1
# 11699   8.517193                       0                    1
# 15412   8.517193                       0                    1
# 11022   8.517193                       0                    1
#
#        AFFILIATION_CompanySponsored  AFFILIATION_Independent  \
# 30989                             1                        0
# 2627                              0                        1
# 11699                             1                        0
# 15412                             0                        1
# 11022                             0                        1
#
#        AFFILIATION_Other  CLASSIFICATION_C1000  CLASSIFICATION_C1200  \
# 30989                  0                     0                     0
# 2627                   0                     0                     0
# 11699                  0                     0                     1
# 15412                  0                     1                     0
# 11022                  0                     0                     0
#
#        CLASSIFICATION_C2000  CLASSIFICATION_Other  ...  ORGANIZATION_Trust  \
# 30989                     1                     0  ...                   0
# 2627                      1                     0  ...                   1
# 11699                     0                     0  ...                   0
# 15412                     0                     0  ...                   1
# 11022                     1                     0  ...                   1
#
#        INCOME_AMT_0  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# 30989             1                  0                       0
# 2627              0                  0                       0
# 11699             1                  0                       0
# 15412             1                  0                       0
# 11022             1                  0                       0
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# 30989                         0                   0                 0
# 2627                          0                   0                 1
# 11699                         0                   0                 0
# 15412                         0                   0                 0
# 11022                         0                   0                 0
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M
# 30989                       0                0                  0
# 2627                        0                0                  0
# 11699                       0                0                  0
# 15412                       0                0                  0
# 11022                       0                0                  0
#
# [5 rows x 25 columns]

# %%
X.describe(include = 'all').round(3)
# Out:
#          ASK_AMT  APPLICATION_TYPE_Other  APPLICATION_TYPE_T3  \
# count  17107.000               17107.000            17107.000
# mean       9.401                   0.208                0.792
# std        1.836                   0.406                0.406
# min        8.517                   0.000                0.000
# 25%        8.517                   0.000                1.000
# 50%        8.517                   0.000                1.000
# 75%        8.993                   0.000                1.000
# max       20.711                   1.000                1.000
#
#        AFFILIATION_CompanySponsored  AFFILIATION_Independent  \
# count                     17107.000                17107.000
# mean                          0.461                    0.536
# std                           0.498                    0.499
# min                           0.000                    0.000
# 25%                           0.000                    0.000
# 50%                           0.000                    1.000
# 75%                           1.000                    1.000
# max                           1.000                    1.000
#
#        AFFILIATION_Other  CLASSIFICATION_C1000  CLASSIFICATION_C1200  \
# count          17107.000             17107.000             17107.000
# mean               0.003                 0.505                 0.144
# std                0.058                 0.500                 0.351
# min                0.000                 0.000                 0.000
# 25%                0.000                 0.000                 0.000
# 50%                0.000                 1.000                 0.000
# 75%                0.000                 1.000                 0.000
# max                1.000                 1.000                 1.000
#
#        CLASSIFICATION_C2000  CLASSIFICATION_Other  ...  ORGANIZATION_Trust  \
# count             17107.000             17107.000  ...           17107.000
# mean                  0.175                 0.176  ...               0.686
# std                   0.380                 0.381  ...               0.464
# min                   0.000                 0.000  ...               0.000
# 25%                   0.000                 0.000  ...               0.000
# 50%                   0.000                 0.000  ...               1.000
# 75%                   0.000                 0.000  ...               1.000
# max                   1.000                 1.000  ...               1.000
#
#        INCOME_AMT_0  INCOME_AMT_1-9999  INCOME_AMT_10000-24999  \
# count     17107.000          17107.000               17107.000
# mean          0.710              0.021                   0.016
# std           0.454              0.143                   0.125
# min           0.000              0.000                   0.000
# 25%           0.000              0.000                   0.000
# 50%           1.000              0.000                   0.000
# 75%           1.000              0.000                   0.000
# max           1.000              1.000                   1.000
#
#        INCOME_AMT_100000-499999  INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  \
# count                 17107.000           17107.000         17107.000
# mean                      0.100               0.007             0.028
# std                       0.299               0.082             0.164
# min                       0.000               0.000             0.000
# 25%                       0.000               0.000             0.000
# 50%                       0.000               0.000             0.000
# 75%                       0.000               0.000             0.000
# max                       1.000               1.000             1.000
#
#        INCOME_AMT_25000-99999  INCOME_AMT_50M+  INCOME_AMT_5M-10M
# count               17107.000        17107.000          17107.000
# mean                    0.110            0.004              0.005
# std                     0.313            0.062              0.073
# min                     0.000            0.000              0.000
# 25%                     0.000            0.000              0.000
# 50%                     0.000            0.000              0.000
# 75%                     0.000            0.000              0.000
# max                     1.000            1.000              1.000
#
# [8 rows x 25 columns]

# %%
# Split the preprocessed data into a training and testing dataset
# Split the data into X_train, X_test, y_train, y_test
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# there was only one value that needed Scaling ASK_AMT
# Therefore I scaled that variable earlier in the code so the whole data set could be exported for testing in other code.

# I Copied the dataframes to the the "standard names" so that "cut and Paste code would work"
X_train_scaled = X_train
X_test_scaled = X_test

# %% [markdown]
# ---
# ## Compile, Train and Evaluate the Model (Step 2)
# Using your knowledge of TensorFlow, you’ll design a neural network, or deep learning model, to create a binary classification model that can predict if an Alphabet Soup–funded organization will be successful based on the features in the dataset. You’ll need to think about how many inputs there are before determining the number of neurons and layers in your model. Once you’ve completed that step, you’ll compile, train, and evaluate your binary classification model to calculate the model’s loss and accuracy.
#
# 1. Continue using the Jupyter Notebook in which you performed the preprocessing steps from Step 1.
#
# 2. Create a neural network model by assigning the number of input features and nodes for each layer using TensorFlow and Keras.
#
# 3. Create the first hidden layer and choose an appropriate activation function.
#
# 4. If necessary, add a second hidden layer with an appropriate activation function.
#
# 5. Create an output layer with an appropriate activation function.
#
# 6. Check the structure of the model.
#
# 7. Compile and train the model.
#
# 8. Create a callback that saves the model's weights every five epochs.
#
# 9. Evaluate the model using the test data to determine the loss and accuracy.
#
# 10. Save and export your results to an HDF5 file. Name the file `AlphabetSoupCharity.h5`.

# %%
# This "bad code" Stops execution here when I do a "Restart", "Clear All Outputs", and "Run All"
Stop Here
# Out:
#   Cell In[33], line 2
#     Stop Here
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ---
# My Auto Hunt
# ---

# %%
inputs = 25
nEpoch = 20
counter = 0
for each_layer1_neuron in (124, 62, 31):
      for each_layer1_activation in ('relu', 'sigmoid'):

            for each_layer2_neuron in (20, 10, 40):
                  for each_layer2_activation in ('relu', 'sigmoid'):

                        for each_layer3_neuron in (0, 5, 15):
                              for each_layer3_activation in ('relu', 'sigmoid'):

                                    for each_layer4_neuron in (0, 6):
                                          for each_layer4_activation in ('relu', 'sigmoid'):

                                                # for each_output_activation in ('sigmoid'):

                                                      # Create a Keras Sequential model and add more than one Dense hidden layer
                                                      nn = tf.keras.models.Sequential()

                                                      # 1st hidden layer with 6 neurons
                                                      # two inputs
                                                      nn.add(tf.keras.layers.Dense(units=each_layer1_neuron, activation=each_layer1_activation, input_dim=inputs))

                                                      # 2nd hidden layer
                                                      if each_layer2_neuron > 0:
                                                            nn.add(tf.keras.layers.Dense(units=each_layer2_neuron, activation=each_layer2_activation))

                                                      # 3rd hidden layer
                                                      if each_layer3_neuron > 0:
                                                            nn.add(tf.keras.layers.Dense(units=each_layer3_neuron, activation=each_layer3_activation))

                                                      # 4rd hidden layer
                                                      if each_layer4_neuron > 0:
                                                            nn.add(tf.keras.layers.Dense(units=each_layer4_neuron, activation=each_layer4_activation))

                                                      # output layer for classification.
                                                      nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

                                                      # Compile the model
                                                      nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
                                                      fit_model = nn.fit(X_train_scaled, y_train, epochs=nEpoch)

                                                      # gather the results
                                                      model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
                                                      data = [model_accuracy,model_loss,nEpoch
                                                            ,inputs
                                                            ,each_layer1_neuron,each_layer2_neuron,each_layer3_neuron,each_layer4_neuron,0,0
                                                            ,each_layer1_activation,each_layer2_activation,each_layer3_activation,each_layer4_activation,0,0
                                                            ,'sigmoid'] #the data

                                                      # write the  results to a file.
                                                      with open ('Run_results.csv', 'a', encoding='utf-8', newline='') as f:
                                                            writer = csv.writer(f) #this is the writer object
                                                            # writer.writerow(column_name) # this will list out the names of the columns which are always the first entrries
                                                            writer.writerow(data) #this is the data
                                                      f.close()
                                                      counter = counter + 1
                                                      print (counter)
# Out:
# Epoch 1/20
# 401/401 [==============================] - 1s 887us/step - loss: 0.6150 - accuracy: 0.6863
# Epoch 2/20
# 401/401 [==============================] - 0s 840us/step - loss: 0.5967 - accuracy: 0.7003
# Epoch 3/20
# 401/401 [==============================] - 0s 773us/step - loss: 0.5913 - accuracy: 0.7052
# Epoch 4/20
# 401/401 [==============================] - 0s 909us/step - loss: 0.5876 - accuracy: 0.7068
# Epoch 5/20
# 401/401 [==============================] - 0s 829us/step - loss: 0.5855 - accuracy: 0.7076
# Epoch 6/20
# 401/401 [==============================] - 0s 776us/step - loss: 0.5837 - accuracy: 0.7127
# Epoch 7/20
# 401/401 [==============================] - 0s 799us/step - loss: 0.5822 - accuracy: 0.7129
# Epoch 8/20
# 401/401 [==============================] - 0s 777us/step - loss: 0.5804 - accuracy: 0.7118
# Epoch 9/20
# 401/401 [==============================] - 0s 878us/step - loss: 0.5797 - accuracy: 0.7127
# Epoch 10/20
# 401/401 [==============================] - 0s 855us/step - loss: 0.5788 - accuracy: 0.7143
# Epoch 11/20
# 401/401 [==============================] - 0s 791us/step - loss: 0.5771 - accuracy: 0.7137
# Epoch 12/20
# 401/401 [==============================] - 0s 878us/step - loss: 0.5770 - accuracy: 0.7143
# Epoch 13/20
# 401/401 [==============================] - 0s 799us/step - loss: 0.5765 - accuracy: 0.7174
# Epoch 14/20
# 401/401 [==============================] - 0s 830us/step - loss: 0.5761 - accuracy: 0.7139
# Epoch 15/20
# 401/401 [==============================] - 0s 960us/step - loss: 0.5769 - accuracy: 0.7127
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7153
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7168
# Epoch 18/20
# 401/401 [==============================] - 0s 966us/step - loss: 0.5748 - accuracy: 0.7154
# Epoch 19/20
# 401/401 [==============================] - 0s 907us/step - loss: 0.5743 - accuracy: 0.7164
# Epoch 20/20
# 401/401 [==============================] - 0s 978us/step - loss: 0.5741 - accuracy: 0.7164
# 134/134 - 0s - loss: 0.5713 - accuracy: 0.7159
# 1
# Epoch 1/20
# 401/401 [==============================] - 1s 924us/step - loss: 0.6200 - accuracy: 0.6731
# Epoch 2/20
# 401/401 [==============================] - 0s 973us/step - loss: 0.5996 - accuracy: 0.6920
# Epoch 3/20
# 401/401 [==============================] - 0s 908us/step - loss: 0.5927 - accuracy: 0.6981
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5895 - accuracy: 0.7031
# Epoch 5/20
# 401/401 [==============================] - 0s 919us/step - loss: 0.5861 - accuracy: 0.7114
# Epoch 6/20
# 401/401 [==============================] - 0s 890us/step - loss: 0.5835 - accuracy: 0.7104
# Epoch 7/20
# 401/401 [==============================] - 0s 885us/step - loss: 0.5809 - accuracy: 0.7116
# Epoch 8/20
# 401/401 [==============================] - 0s 848us/step - loss: 0.5810 - accuracy: 0.7105
# Epoch 9/20
# 401/401 [==============================] - 0s 858us/step - loss: 0.5793 - accuracy: 0.7132
# Epoch 10/20
# 401/401 [==============================] - 0s 869us/step - loss: 0.5786 - accuracy: 0.7147
# Epoch 11/20
# 401/401 [==============================] - 0s 855us/step - loss: 0.5797 - accuracy: 0.7125
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7139
# Epoch 13/20
# 401/401 [==============================] - 0s 872us/step - loss: 0.5771 - accuracy: 0.7135
# Epoch 14/20
# 401/401 [==============================] - 0s 853us/step - loss: 0.5775 - accuracy: 0.7122
# Epoch 15/20
# 401/401 [==============================] - 0s 873us/step - loss: 0.5761 - accuracy: 0.7129
# Epoch 16/20
# 401/401 [==============================] - 0s 863us/step - loss: 0.5765 - accuracy: 0.7145
# Epoch 17/20
# 401/401 [==============================] - 0s 864us/step - loss: 0.5754 - accuracy: 0.7147
# Epoch 18/20
# 401/401 [==============================] - 0s 874us/step - loss: 0.5747 - accuracy: 0.7167
# Epoch 19/20
# 401/401 [==============================] - 0s 997us/step - loss: 0.5753 - accuracy: 0.7148
# Epoch 20/20
# 401/401 [==============================] - 0s 873us/step - loss: 0.5756 - accuracy: 0.7147
# 134/134 - 0s - loss: 0.5674 - accuracy: 0.7155
# 2
# Epoch 1/20
# 401/401 [==============================] - 1s 988us/step - loss: 0.6282 - accuracy: 0.6682
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6041 - accuracy: 0.6958
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5991 - accuracy: 0.6991
# Epoch 4/20
# 401/401 [==============================] - 0s 975us/step - loss: 0.5942 - accuracy: 0.6997
# Epoch 5/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5911 - accuracy: 0.7010
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5885 - accuracy: 0.7041
# Epoch 7/20
# 401/401 [==============================] - 0s 927us/step - loss: 0.5855 - accuracy: 0.7096
# Epoch 8/20
# 401/401 [==============================] - 0s 931us/step - loss: 0.5829 - accuracy: 0.7108
# Epoch 9/20
# 401/401 [==============================] - 0s 916us/step - loss: 0.5812 - accuracy: 0.7136
# Epoch 10/20
# 401/401 [==============================] - 0s 923us/step - loss: 0.5797 - accuracy: 0.7148
# Epoch 11/20
# 401/401 [==============================] - 0s 941us/step - loss: 0.5792 - accuracy: 0.7147
# Epoch 12/20
# 401/401 [==============================] - 0s 988us/step - loss: 0.5778 - accuracy: 0.7148
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5770 - accuracy: 0.7149
# Epoch 14/20
# 401/401 [==============================] - 0s 947us/step - loss: 0.5775 - accuracy: 0.7148
# Epoch 15/20
# 401/401 [==============================] - 0s 920us/step - loss: 0.5760 - accuracy: 0.7164
# Epoch 16/20
# 401/401 [==============================] - 0s 928us/step - loss: 0.5769 - accuracy: 0.7154
# Epoch 17/20
# 401/401 [==============================] - 0s 973us/step - loss: 0.5751 - accuracy: 0.7154
# Epoch 18/20
# 401/401 [==============================] - 0s 937us/step - loss: 0.5750 - accuracy: 0.7166
# Epoch 19/20
# 401/401 [==============================] - 0s 938us/step - loss: 0.5745 - accuracy: 0.7171
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5742 - accuracy: 0.7167
# 134/134 - 0s - loss: 0.5750 - accuracy: 0.7159
# 3
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6263 - accuracy: 0.6740
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6006 - accuracy: 0.6948
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5941 - accuracy: 0.6997
# Epoch 4/20
# 401/401 [==============================] - 0s 929us/step - loss: 0.5892 - accuracy: 0.7034
# Epoch 5/20
# 401/401 [==============================] - 0s 927us/step - loss: 0.5869 - accuracy: 0.7081
# Epoch 6/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5846 - accuracy: 0.7082
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.7121
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5809 - accuracy: 0.7127
# Epoch 9/20
# 401/401 [==============================] - 0s 990us/step - loss: 0.5801 - accuracy: 0.7091
# Epoch 10/20
# 401/401 [==============================] - 0s 959us/step - loss: 0.5791 - accuracy: 0.7125
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5788 - accuracy: 0.7153
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5785 - accuracy: 0.7145
# Epoch 13/20
# 401/401 [==============================] - 0s 946us/step - loss: 0.5777 - accuracy: 0.7147
# Epoch 14/20
# 401/401 [==============================] - 0s 870us/step - loss: 0.5785 - accuracy: 0.7157
# Epoch 15/20
# 401/401 [==============================] - 0s 938us/step - loss: 0.5763 - accuracy: 0.7147
# Epoch 16/20
# 401/401 [==============================] - 0s 982us/step - loss: 0.5765 - accuracy: 0.7142
# Epoch 17/20
# 401/401 [==============================] - 0s 940us/step - loss: 0.5760 - accuracy: 0.7168
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5760 - accuracy: 0.7177
# Epoch 19/20
# 401/401 [==============================] - 0s 911us/step - loss: 0.5745 - accuracy: 0.7174
# Epoch 20/20
# 401/401 [==============================] - 0s 905us/step - loss: 0.5750 - accuracy: 0.7164
# 134/134 - 0s - loss: 0.5706 - accuracy: 0.7164
# 4
# Epoch 1/20
# 401/401 [==============================] - 1s 882us/step - loss: 0.6187 - accuracy: 0.6754
# Epoch 2/20
# 401/401 [==============================] - 0s 883us/step - loss: 0.5977 - accuracy: 0.6973
# Epoch 3/20
# 401/401 [==============================] - 0s 938us/step - loss: 0.5894 - accuracy: 0.7022
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5859 - accuracy: 0.7097
# Epoch 5/20
# 401/401 [==============================] - 0s 890us/step - loss: 0.5836 - accuracy: 0.7120
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5813 - accuracy: 0.7132
# Epoch 7/20
# 401/401 [==============================] - 0s 930us/step - loss: 0.5806 - accuracy: 0.7132
# Epoch 8/20
# 401/401 [==============================] - 0s 866us/step - loss: 0.5811 - accuracy: 0.7122
# Epoch 9/20
# 401/401 [==============================] - 0s 939us/step - loss: 0.5783 - accuracy: 0.7150
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5778 - accuracy: 0.7121
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5768 - accuracy: 0.7145
# Epoch 12/20
# 401/401 [==============================] - 0s 979us/step - loss: 0.5755 - accuracy: 0.7148
# Epoch 13/20
# 401/401 [==============================] - 0s 984us/step - loss: 0.5770 - accuracy: 0.7173
# Epoch 14/20
# 401/401 [==============================] - 0s 973us/step - loss: 0.5765 - accuracy: 0.7144
# Epoch 15/20
# 401/401 [==============================] - 0s 926us/step - loss: 0.5762 - accuracy: 0.7139
# Epoch 16/20
# 401/401 [==============================] - 0s 887us/step - loss: 0.5746 - accuracy: 0.7154
# Epoch 17/20
# 401/401 [==============================] - 0s 984us/step - loss: 0.5749 - accuracy: 0.7157
# Epoch 18/20
# 401/401 [==============================] - 0s 874us/step - loss: 0.5746 - accuracy: 0.7157
# Epoch 19/20
# 401/401 [==============================] - 0s 883us/step - loss: 0.5743 - accuracy: 0.7180
# Epoch 20/20
# 401/401 [==============================] - 0s 909us/step - loss: 0.5739 - accuracy: 0.7145
# 134/134 - 0s - loss: 0.5693 - accuracy: 0.7157
# 5
# Epoch 1/20
# 401/401 [==============================] - 1s 873us/step - loss: 0.6146 - accuracy: 0.6839
# Epoch 2/20
# 401/401 [==============================] - 0s 942us/step - loss: 0.5945 - accuracy: 0.7026
# Epoch 3/20
# 401/401 [==============================] - 0s 961us/step - loss: 0.5904 - accuracy: 0.7020
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5863 - accuracy: 0.7087
# Epoch 5/20
# 401/401 [==============================] - 0s 920us/step - loss: 0.5846 - accuracy: 0.7100
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.7101
# Epoch 7/20
# 401/401 [==============================] - 0s 991us/step - loss: 0.5809 - accuracy: 0.7108
# Epoch 8/20
# 401/401 [==============================] - 0s 901us/step - loss: 0.5808 - accuracy: 0.7107
# Epoch 9/20
# 401/401 [==============================] - 0s 925us/step - loss: 0.5790 - accuracy: 0.7109
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5784 - accuracy: 0.7122
# Epoch 11/20
# 401/401 [==============================] - 0s 897us/step - loss: 0.5789 - accuracy: 0.7134
# Epoch 12/20
# 401/401 [==============================] - 0s 943us/step - loss: 0.5768 - accuracy: 0.7144
# Epoch 13/20
# 401/401 [==============================] - 0s 910us/step - loss: 0.5780 - accuracy: 0.7118
# Epoch 14/20
# 401/401 [==============================] - 0s 949us/step - loss: 0.5769 - accuracy: 0.7122
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.7156
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7135
# Epoch 17/20
# 401/401 [==============================] - 0s 906us/step - loss: 0.5753 - accuracy: 0.7151
# Epoch 18/20
# 401/401 [==============================] - 0s 919us/step - loss: 0.5746 - accuracy: 0.7157
# Epoch 19/20
# 401/401 [==============================] - 0s 910us/step - loss: 0.5758 - accuracy: 0.7148
# Epoch 20/20
# 401/401 [==============================] - 0s 932us/step - loss: 0.5747 - accuracy: 0.7165
# 134/134 - 0s - loss: 0.5711 - accuracy: 0.7145
# 6
# Epoch 1/20
# 401/401 [==============================] - 1s 925us/step - loss: 0.6426 - accuracy: 0.6581
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6150 - accuracy: 0.6965
# Epoch 3/20
# 401/401 [==============================] - 0s 950us/step - loss: 0.6083 - accuracy: 0.6984
# Epoch 4/20
# 401/401 [==============================] - 0s 994us/step - loss: 0.6035 - accuracy: 0.7005
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.6998
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.7018
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5888 - accuracy: 0.7071
# Epoch 8/20
# 401/401 [==============================] - 0s 967us/step - loss: 0.5878 - accuracy: 0.7106
# Epoch 9/20
# 401/401 [==============================] - 0s 938us/step - loss: 0.5844 - accuracy: 0.7147
# Epoch 10/20
# 401/401 [==============================] - 0s 940us/step - loss: 0.5828 - accuracy: 0.7153
# Epoch 11/20
# 401/401 [==============================] - 0s 934us/step - loss: 0.5826 - accuracy: 0.7146
# Epoch 12/20
# 401/401 [==============================] - 0s 958us/step - loss: 0.5808 - accuracy: 0.7140
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5803 - accuracy: 0.7147
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5796 - accuracy: 0.7141
# Epoch 15/20
# 401/401 [==============================] - 0s 937us/step - loss: 0.5801 - accuracy: 0.7157
# Epoch 16/20
# 401/401 [==============================] - 0s 952us/step - loss: 0.5794 - accuracy: 0.7160
# Epoch 17/20
# 401/401 [==============================] - 0s 927us/step - loss: 0.5780 - accuracy: 0.7148
# Epoch 18/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5775 - accuracy: 0.7154
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7175
# Epoch 20/20
# 401/401 [==============================] - 0s 890us/step - loss: 0.5769 - accuracy: 0.7154
# 134/134 - 0s - loss: 0.5707 - accuracy: 0.7169
# 7
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6368 - accuracy: 0.6465
# Epoch 2/20
# 401/401 [==============================] - 0s 941us/step - loss: 0.6046 - accuracy: 0.6964
# Epoch 3/20
# 401/401 [==============================] - 0s 935us/step - loss: 0.5985 - accuracy: 0.7001
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5951 - accuracy: 0.6992
# Epoch 5/20
# 401/401 [==============================] - 0s 959us/step - loss: 0.5916 - accuracy: 0.7005
# Epoch 6/20
# 401/401 [==============================] - 0s 946us/step - loss: 0.5881 - accuracy: 0.7027
# Epoch 7/20
# 401/401 [==============================] - 0s 956us/step - loss: 0.5869 - accuracy: 0.7036
# Epoch 8/20
# 401/401 [==============================] - 0s 916us/step - loss: 0.5850 - accuracy: 0.7101
# Epoch 9/20
# 401/401 [==============================] - 0s 935us/step - loss: 0.5830 - accuracy: 0.7111
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5820 - accuracy: 0.7122
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5808 - accuracy: 0.7134
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5798 - accuracy: 0.7121
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7138
# Epoch 14/20
# 401/401 [==============================] - 0s 997us/step - loss: 0.5787 - accuracy: 0.7123
# Epoch 15/20
# 401/401 [==============================] - 0s 986us/step - loss: 0.5779 - accuracy: 0.7161
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5785 - accuracy: 0.7152
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5763 - accuracy: 0.7149
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5763 - accuracy: 0.7162
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7168
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5753 - accuracy: 0.7157
# 134/134 - 0s - loss: 0.5690 - accuracy: 0.7192
# 8
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6364 - accuracy: 0.6711
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6156 - accuracy: 0.6945
# Epoch 3/20
# 401/401 [==============================] - 0s 968us/step - loss: 0.6091 - accuracy: 0.6983
# Epoch 4/20
# 401/401 [==============================] - 0s 966us/step - loss: 0.6032 - accuracy: 0.6986
# Epoch 5/20
# 401/401 [==============================] - 0s 958us/step - loss: 0.6024 - accuracy: 0.6991
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6015 - accuracy: 0.6989
# Epoch 7/20
# 401/401 [==============================] - 0s 937us/step - loss: 0.5985 - accuracy: 0.7016
# Epoch 8/20
# 401/401 [==============================] - 0s 936us/step - loss: 0.5979 - accuracy: 0.7044
# Epoch 9/20
# 401/401 [==============================] - 0s 925us/step - loss: 0.5971 - accuracy: 0.7050
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.7053
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5955 - accuracy: 0.7052
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5957 - accuracy: 0.7058
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5950 - accuracy: 0.7051
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.7088
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5945 - accuracy: 0.7069
# Epoch 16/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5937 - accuracy: 0.7069
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5938 - accuracy: 0.7072
# Epoch 18/20
# 401/401 [==============================] - 0s 955us/step - loss: 0.5933 - accuracy: 0.7082
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5934 - accuracy: 0.7083
# Epoch 20/20
# 401/401 [==============================] - 0s 982us/step - loss: 0.5930 - accuracy: 0.7083
# 134/134 - 0s - loss: 0.5867 - accuracy: 0.7098
# 9
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6565 - accuracy: 0.6655
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6219 - accuracy: 0.6930
# Epoch 3/20
# 401/401 [==============================] - 0s 1000us/step - loss: 0.6091 - accuracy: 0.7004
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6035 - accuracy: 0.7016
# Epoch 5/20
# 401/401 [==============================] - 0s 966us/step - loss: 0.5966 - accuracy: 0.7058
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5910 - accuracy: 0.7097
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5840 - accuracy: 0.7137
# Epoch 8/20
# 401/401 [==============================] - 0s 982us/step - loss: 0.5824 - accuracy: 0.7101
# Epoch 9/20
# 401/401 [==============================] - 0s 994us/step - loss: 0.5798 - accuracy: 0.7142
# Epoch 10/20
# 401/401 [==============================] - 0s 975us/step - loss: 0.5784 - accuracy: 0.7133
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5774 - accuracy: 0.7122
# Epoch 12/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5775 - accuracy: 0.7133
# Epoch 13/20
# 401/401 [==============================] - 0s 981us/step - loss: 0.5770 - accuracy: 0.7143
# Epoch 14/20
# 401/401 [==============================] - 0s 979us/step - loss: 0.5752 - accuracy: 0.7147
# Epoch 15/20
# 401/401 [==============================] - 0s 970us/step - loss: 0.5749 - accuracy: 0.7164
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5753 - accuracy: 0.7165
# Epoch 17/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5748 - accuracy: 0.7164
# Epoch 18/20
# 401/401 [==============================] - 0s 933us/step - loss: 0.5741 - accuracy: 0.7179
# Epoch 19/20
# 401/401 [==============================] - 0s 938us/step - loss: 0.5738 - accuracy: 0.7161
# Epoch 20/20
# 401/401 [==============================] - 0s 923us/step - loss: 0.5739 - accuracy: 0.7188
# 134/134 - 0s - loss: 0.5709 - accuracy: 0.7136
# 10
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6264 - accuracy: 0.6798
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6010 - accuracy: 0.7001
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5918 - accuracy: 0.7052
# Epoch 4/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5879 - accuracy: 0.7065
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5851 - accuracy: 0.7118
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5828 - accuracy: 0.7089
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.7128
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5812 - accuracy: 0.7111
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7129
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5783 - accuracy: 0.7124
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.7129
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7133
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5764 - accuracy: 0.7140
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5767 - accuracy: 0.7131
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5762 - accuracy: 0.7137
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5763 - accuracy: 0.7140
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5759 - accuracy: 0.7159
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5746 - accuracy: 0.7147
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7157
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5737 - accuracy: 0.7175
# 134/134 - 0s - loss: 0.5705 - accuracy: 0.7173
# 11
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6498 - accuracy: 0.6549
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6072 - accuracy: 0.6921
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5975 - accuracy: 0.6984
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5908 - accuracy: 0.7068
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5878 - accuracy: 0.7097
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5834 - accuracy: 0.7129
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5826 - accuracy: 0.7133
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7139
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5795 - accuracy: 0.7121
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.7147
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5769 - accuracy: 0.7169
# Epoch 12/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5774 - accuracy: 0.7126
# Epoch 13/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5766 - accuracy: 0.7132
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5755 - accuracy: 0.7154
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7147
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.7157
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7160
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5744 - accuracy: 0.7169
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5738 - accuracy: 0.7171
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5735 - accuracy: 0.7175
# 134/134 - 0s - loss: 0.5693 - accuracy: 0.7157
# 12
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6317 - accuracy: 0.6659
# Epoch 2/20
# 401/401 [==============================] - 0s 957us/step - loss: 0.6051 - accuracy: 0.6952
# Epoch 3/20
# 401/401 [==============================] - 0s 972us/step - loss: 0.6001 - accuracy: 0.6977
# Epoch 4/20
# 401/401 [==============================] - 0s 954us/step - loss: 0.5956 - accuracy: 0.7017
# Epoch 5/20
# 401/401 [==============================] - 0s 949us/step - loss: 0.5913 - accuracy: 0.7061
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5873 - accuracy: 0.7090
# Epoch 7/20
# 401/401 [==============================] - 0s 942us/step - loss: 0.5852 - accuracy: 0.7087
# Epoch 8/20
# 401/401 [==============================] - 0s 931us/step - loss: 0.5823 - accuracy: 0.7140
# Epoch 9/20
# 401/401 [==============================] - 0s 951us/step - loss: 0.5811 - accuracy: 0.7142
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5803 - accuracy: 0.7150
# Epoch 11/20
# 401/401 [==============================] - 0s 977us/step - loss: 0.5790 - accuracy: 0.7163
# Epoch 12/20
# 401/401 [==============================] - 0s 957us/step - loss: 0.5780 - accuracy: 0.7165
# Epoch 13/20
# 401/401 [==============================] - 0s 914us/step - loss: 0.5779 - accuracy: 0.7148
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7155
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5774 - accuracy: 0.7137
# Epoch 16/20
# 401/401 [==============================] - 0s 972us/step - loss: 0.5766 - accuracy: 0.7166
# Epoch 17/20
# 401/401 [==============================] - 0s 948us/step - loss: 0.5756 - accuracy: 0.7154
# Epoch 18/20
# 401/401 [==============================] - 0s 958us/step - loss: 0.5759 - accuracy: 0.7148
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7178
# Epoch 20/20
# 401/401 [==============================] - 0s 941us/step - loss: 0.5749 - accuracy: 0.7172
# 134/134 - 0s - loss: 0.5702 - accuracy: 0.7152
# 13
# Epoch 1/20
# 401/401 [==============================] - 1s 937us/step - loss: 0.6368 - accuracy: 0.6445
# Epoch 2/20
# 401/401 [==============================] - 0s 943us/step - loss: 0.6071 - accuracy: 0.6902
# Epoch 3/20
# 401/401 [==============================] - 0s 969us/step - loss: 0.6034 - accuracy: 0.6981
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.6988
# Epoch 5/20
# 401/401 [==============================] - 0s 976us/step - loss: 0.5963 - accuracy: 0.7016
# Epoch 6/20
# 401/401 [==============================] - 0s 927us/step - loss: 0.5923 - accuracy: 0.7031
# Epoch 7/20
# 401/401 [==============================] - 0s 924us/step - loss: 0.5883 - accuracy: 0.7078
# Epoch 8/20
# 401/401 [==============================] - 0s 935us/step - loss: 0.5862 - accuracy: 0.7080
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.7093
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5833 - accuracy: 0.7122
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5815 - accuracy: 0.7151
# Epoch 12/20
# 401/401 [==============================] - 0s 939us/step - loss: 0.5810 - accuracy: 0.7141
# Epoch 13/20
# 401/401 [==============================] - 0s 987us/step - loss: 0.5794 - accuracy: 0.7131
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5786 - accuracy: 0.7138
# Epoch 15/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5785 - accuracy: 0.7143
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7165
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7165
# Epoch 18/20
# 401/401 [==============================] - 0s 963us/step - loss: 0.5763 - accuracy: 0.7166
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5757 - accuracy: 0.7150
# Epoch 20/20
# 401/401 [==============================] - 0s 951us/step - loss: 0.5753 - accuracy: 0.7169
# 134/134 - 0s - loss: 0.5714 - accuracy: 0.7155
# 14
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6282 - accuracy: 0.6659
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6030 - accuracy: 0.6971
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5965 - accuracy: 0.7005
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5909 - accuracy: 0.7028
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5865 - accuracy: 0.7087
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5844 - accuracy: 0.7100
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5829 - accuracy: 0.7105
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.7136
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7147
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.7135
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.7147
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5773 - accuracy: 0.7156
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5769 - accuracy: 0.7184
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5758 - accuracy: 0.7145
# Epoch 15/20
# 401/401 [==============================] - 0s 989us/step - loss: 0.5756 - accuracy: 0.7167
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5760 - accuracy: 0.7153
# Epoch 17/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5751 - accuracy: 0.7171
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7173
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5741 - accuracy: 0.7172
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5737 - accuracy: 0.7194
# 134/134 - 0s - loss: 0.5692 - accuracy: 0.7164
# 15
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6598 - accuracy: 0.6073
# Epoch 2/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6132 - accuracy: 0.6912
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6064 - accuracy: 0.6973
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6028 - accuracy: 0.6995
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.7007
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5975 - accuracy: 0.7000
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5955 - accuracy: 0.7020
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5932 - accuracy: 0.7021
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5917 - accuracy: 0.7003
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.7009
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5877 - accuracy: 0.7034
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5845 - accuracy: 0.7057
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5827 - accuracy: 0.7104
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.7136
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5805 - accuracy: 0.7144
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5804 - accuracy: 0.7136
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.7139
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.7151
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7157
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5777 - accuracy: 0.7155
# 134/134 - 0s - loss: 0.5717 - accuracy: 0.7061
# 16
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6175 - accuracy: 0.6818
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5975 - accuracy: 0.7002
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5908 - accuracy: 0.7060
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.7066
# Epoch 5/20
# 401/401 [==============================] - 0s 991us/step - loss: 0.5839 - accuracy: 0.7124
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.7128
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7122
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5787 - accuracy: 0.7121
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7156
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5781 - accuracy: 0.7134
# Epoch 11/20
# 401/401 [==============================] - 0s 999us/step - loss: 0.5772 - accuracy: 0.7154
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5770 - accuracy: 0.7125
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5757 - accuracy: 0.7148
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7155
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5746 - accuracy: 0.7140
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5746 - accuracy: 0.7147
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7155
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5738 - accuracy: 0.7159
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.7161
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5735 - accuracy: 0.7174
# 134/134 - 0s - loss: 0.5726 - accuracy: 0.7155
# 17
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6219 - accuracy: 0.6815
# Epoch 2/20
# 401/401 [==============================] - 0s 994us/step - loss: 0.5963 - accuracy: 0.6983
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5905 - accuracy: 0.7058
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5869 - accuracy: 0.7064
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5847 - accuracy: 0.7083
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5831 - accuracy: 0.7104
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5814 - accuracy: 0.7127
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5796 - accuracy: 0.7097
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5791 - accuracy: 0.7136
# Epoch 10/20
# 401/401 [==============================] - 0s 982us/step - loss: 0.5769 - accuracy: 0.7155
# Epoch 11/20
# 401/401 [==============================] - 0s 972us/step - loss: 0.5770 - accuracy: 0.7118
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7140
# Epoch 13/20
# 401/401 [==============================] - 0s 971us/step - loss: 0.5753 - accuracy: 0.7154
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7168
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7168
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5743 - accuracy: 0.7168
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5750 - accuracy: 0.7172
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7163
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5736 - accuracy: 0.7170
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5724 - accuracy: 0.7187
# 134/134 - 0s - loss: 0.5678 - accuracy: 0.7148
# 18
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6155 - accuracy: 0.6848
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.7034
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5892 - accuracy: 0.7090
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5862 - accuracy: 0.7095
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5853 - accuracy: 0.7115
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.7118
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5810 - accuracy: 0.7125
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7145
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.7147
# Epoch 10/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5790 - accuracy: 0.7131
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7127
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7141
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7158
# Epoch 14/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5759 - accuracy: 0.7146
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5755 - accuracy: 0.7164
# Epoch 16/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5757 - accuracy: 0.7141
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5750 - accuracy: 0.7179
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5745 - accuracy: 0.7174
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5734 - accuracy: 0.7192
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5736 - accuracy: 0.7177
# 134/134 - 0s - loss: 0.5699 - accuracy: 0.7171
# 19
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6388 - accuracy: 0.6599
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6043 - accuracy: 0.6974
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5968 - accuracy: 0.7020
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5903 - accuracy: 0.7080
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5875 - accuracy: 0.7082
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5843 - accuracy: 0.7130
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5818 - accuracy: 0.7141
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7133
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5803 - accuracy: 0.7154
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5788 - accuracy: 0.7136
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.7147
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7146
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5779 - accuracy: 0.7143
# Epoch 14/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5761 - accuracy: 0.7166
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5766 - accuracy: 0.7174
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5750 - accuracy: 0.7168
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7178
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7160
# Epoch 19/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5746 - accuracy: 0.7181
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5739 - accuracy: 0.7164
# 134/134 - 0s - loss: 0.5716 - accuracy: 0.7143
# 20
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6266 - accuracy: 0.6714
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5991 - accuracy: 0.6973
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.7026
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5879 - accuracy: 0.7065
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5855 - accuracy: 0.7095
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5832 - accuracy: 0.7099
# Epoch 7/20
# 401/401 [==============================] - 0s 995us/step - loss: 0.5813 - accuracy: 0.7113
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5791 - accuracy: 0.7137
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5792 - accuracy: 0.7122
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.7145
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7146
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5774 - accuracy: 0.7136
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5770 - accuracy: 0.7139
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5761 - accuracy: 0.7149
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5749 - accuracy: 0.7161
# Epoch 16/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5744 - accuracy: 0.7166
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5754 - accuracy: 0.7149
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5748 - accuracy: 0.7143
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5747 - accuracy: 0.7167
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5736 - accuracy: 0.7178
# 134/134 - 0s - loss: 0.5733 - accuracy: 0.7131
# 21
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6463 - accuracy: 0.6401
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6024 - accuracy: 0.6984
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5950 - accuracy: 0.7016
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5889 - accuracy: 0.7073
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5865 - accuracy: 0.7103
# Epoch 6/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5841 - accuracy: 0.7121
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5822 - accuracy: 0.7130
# Epoch 8/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5806 - accuracy: 0.7140
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5800 - accuracy: 0.7141
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5794 - accuracy: 0.7171
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5792 - accuracy: 0.7163
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5782 - accuracy: 0.7143
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5781 - accuracy: 0.7150
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5771 - accuracy: 0.7144
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5770 - accuracy: 0.7167
# Epoch 16/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5756 - accuracy: 0.7157
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7172
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5756 - accuracy: 0.7163
# Epoch 19/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5751 - accuracy: 0.7144
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5751 - accuracy: 0.7155
# 134/134 - 0s - loss: 0.5710 - accuracy: 0.7138
# 22
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6488 - accuracy: 0.6348
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6164 - accuracy: 0.6933
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6096 - accuracy: 0.6971
# Epoch 4/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6049 - accuracy: 0.6983
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 0.6986
# Epoch 6/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6014 - accuracy: 0.7005
# Epoch 7/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6011 - accuracy: 0.7006
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5989 - accuracy: 0.7001
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5959 - accuracy: 0.7005
# Epoch 10/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5922 - accuracy: 0.7041
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.7097
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5870 - accuracy: 0.7096
# Epoch 13/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5856 - accuracy: 0.7124
# Epoch 14/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5845 - accuracy: 0.7119
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5824 - accuracy: 0.7155
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5816 - accuracy: 0.7137
# Epoch 17/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5804 - accuracy: 0.7137
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7159
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5790 - accuracy: 0.7158
# Epoch 20/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5778 - accuracy: 0.7176
# 134/134 - 0s - loss: 0.5739 - accuracy: 0.7152
# 23
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6527 - accuracy: 0.6274
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6080 - accuracy: 0.6948
# Epoch 3/20
# ...
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5872 - accuracy: 0.7066
# Epoch 12/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5866 - accuracy: 0.7070
# Epoch 13/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5849 - accuracy: 0.7066
# Epoch 14/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5841 - accuracy: 0.7087
# Epoch 15/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5830 - accuracy: 0.7090
# Epoch 16/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5817 - accuracy: 0.7094
# Epoch 17/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5804 - accuracy: 0.7136
# Epoch 18/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5798 - accuracy: 0.7113
# Epoch 19/20
# 401/401 [==============================] - 3s 7ms/step - loss: 0.5799 - accuracy: 0.7123
# Epoch 20/20
# 401/401 [==============================] - 3s 8ms/step - loss: 0.5789 - accuracy: 0.7129
# 134/134 - 1s - loss: 0.5708 - accuracy: 0.7136
# 835
# Epoch 1/20
# 401/401 [==============================] - 2s 3ms/step - loss: 0.6511 - accuracy: 0.6230
# Epoch 2/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.6076 - accuracy: 0.6913
# Epoch 3/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.6036 - accuracy: 0.6963
# Epoch 4/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.6013 - accuracy: 0.6980
# Epoch 5/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5983 - accuracy: 0.6991
# Epoch 6/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5960 - accuracy: 0.7005
# Epoch 7/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5937 - accuracy: 0.7001
# Epoch 8/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5922 - accuracy: 0.6999
# Epoch 9/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5907 - accuracy: 0.6998
# Epoch 10/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5894 - accuracy: 0.7023
# Epoch 11/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5878 - accuracy: 0.7022
# Epoch 12/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5868 - accuracy: 0.7074
# Epoch 13/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5853 - accuracy: 0.7091
# Epoch 14/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5850 - accuracy: 0.7070
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5839 - accuracy: 0.7108
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5833 - accuracy: 0.7104
# Epoch 17/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5818 - accuracy: 0.7122
# Epoch 18/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5816 - accuracy: 0.7103
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5809 - accuracy: 0.7109
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5801 - accuracy: 0.7127
# 134/134 - 0s - loss: 0.5718 - accuracy: 0.7131
# 836
# Epoch 1/20
# 401/401 [==============================] - 2s 1ms/step - loss: 0.6477 - accuracy: 0.6314
# Epoch 2/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.6072 - accuracy: 0.6903
# Epoch 3/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6020 - accuracy: 0.6964
# Epoch 4/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5974 - accuracy: 0.6972
# Epoch 5/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5945 - accuracy: 0.7000
# Epoch 6/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5918 - accuracy: 0.7009
# Epoch 7/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5902 - accuracy: 0.7041
# Epoch 8/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5892 - accuracy: 0.7030
# Epoch 9/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5888 - accuracy: 0.7045
# Epoch 10/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5874 - accuracy: 0.7071
# Epoch 11/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5861 - accuracy: 0.7081
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.7067
# Epoch 13/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5833 - accuracy: 0.7103
# Epoch 14/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5829 - accuracy: 0.7111
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5825 - accuracy: 0.7102
# Epoch 16/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5818 - accuracy: 0.7111
# Epoch 17/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5808 - accuracy: 0.7097
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5803 - accuracy: 0.7135
# Epoch 19/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5798 - accuracy: 0.7125
# Epoch 20/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5793 - accuracy: 0.7126
# 134/134 - 0s - loss: 0.5710 - accuracy: 0.7126
# 837
# Epoch 1/20
# 401/401 [==============================] - 2s 3ms/step - loss: 0.6524 - accuracy: 0.6235
# Epoch 2/20
# 401/401 [==============================] - 2s 5ms/step - loss: 0.6076 - accuracy: 0.6912
# Epoch 3/20
# 401/401 [==============================] - 4s 10ms/step - loss: 0.6021 - accuracy: 0.6949
# Epoch 4/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5979 - accuracy: 0.6969
# Epoch 5/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5944 - accuracy: 0.6978
# Epoch 6/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5927 - accuracy: 0.6984
# Epoch 7/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5909 - accuracy: 0.7030
# Epoch 8/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5902 - accuracy: 0.7028
# Epoch 9/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5885 - accuracy: 0.7073
# Epoch 10/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5881 - accuracy: 0.7040
# Epoch 11/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5871 - accuracy: 0.7065
# Epoch 12/20
# 401/401 [==============================] - 1s 4ms/step - loss: 0.5857 - accuracy: 0.7062
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5864 - accuracy: 0.7080
# Epoch 14/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5848 - accuracy: 0.7097
# Epoch 15/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5842 - accuracy: 0.7101
# Epoch 16/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5839 - accuracy: 0.7056
# Epoch 17/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5835 - accuracy: 0.7065
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5824 - accuracy: 0.7086
# Epoch 19/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5824 - accuracy: 0.7098
# Epoch 20/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5815 - accuracy: 0.7096
# 134/134 - 0s - loss: 0.5748 - accuracy: 0.7094
# 838
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6713 - accuracy: 0.5860
# Epoch 2/20
# 401/401 [==============================] - 2s 5ms/step - loss: 0.6111 - accuracy: 0.6899
# Epoch 3/20
# 401/401 [==============================] - 1s 4ms/step - loss: 0.6048 - accuracy: 0.6974
# Epoch 4/20
# 401/401 [==============================] - 3s 9ms/step - loss: 0.6014 - accuracy: 0.6985
# Epoch 5/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5979 - accuracy: 0.7010
# Epoch 6/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5957 - accuracy: 0.6986
# Epoch 7/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5931 - accuracy: 0.6994
# Epoch 8/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5914 - accuracy: 0.7019
# Epoch 9/20
# 401/401 [==============================] - 2s 6ms/step - loss: 0.5909 - accuracy: 0.7005
# Epoch 10/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5889 - accuracy: 0.7031
# Epoch 11/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5881 - accuracy: 0.7053
# Epoch 12/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5877 - accuracy: 0.7019
# Epoch 13/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5878 - accuracy: 0.7072
# Epoch 14/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5865 - accuracy: 0.7077
# Epoch 15/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5854 - accuracy: 0.7080
# Epoch 16/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5847 - accuracy: 0.7081
# Epoch 17/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5847 - accuracy: 0.7093
# Epoch 18/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5831 - accuracy: 0.7104
# Epoch 19/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5827 - accuracy: 0.7105
# Epoch 20/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5815 - accuracy: 0.7109
# 134/134 - 1s - loss: 0.5780 - accuracy: 0.7014
# 839
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6996 - accuracy: 0.5240
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6284 - accuracy: 0.6913
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6052 - accuracy: 0.7004
# Epoch 4/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6029 - accuracy: 0.7000
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.7012
# Epoch 6/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5999 - accuracy: 0.7006
# Epoch 7/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5982 - accuracy: 0.7021
# Epoch 8/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5966 - accuracy: 0.7020
# Epoch 9/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5953 - accuracy: 0.6989
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.6997
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5926 - accuracy: 0.7005
# Epoch 12/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5911 - accuracy: 0.7037
# Epoch 13/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5901 - accuracy: 0.7026
# Epoch 14/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5895 - accuracy: 0.7057
# Epoch 15/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5888 - accuracy: 0.7074
# Epoch 16/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5883 - accuracy: 0.7072
# Epoch 17/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5865 - accuracy: 0.7089
# Epoch 18/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5861 - accuracy: 0.7077
# Epoch 19/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5853 - accuracy: 0.7068
# Epoch 20/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5846 - accuracy: 0.7082
# 134/134 - 0s - loss: 0.5773 - accuracy: 0.7084
# 840
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6541 - accuracy: 0.6235
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6107 - accuracy: 0.6908
# Epoch 3/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6077 - accuracy: 0.6927
# Epoch 4/20
# 401/401 [==============================] - 0s 903us/step - loss: 0.6054 - accuracy: 0.6928
# Epoch 5/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6043 - accuracy: 0.6923
# Epoch 6/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6031 - accuracy: 0.6921
# Epoch 7/20
# 401/401 [==============================] - 0s 996us/step - loss: 0.6011 - accuracy: 0.6921
# Epoch 8/20
# 401/401 [==============================] - 0s 966us/step - loss: 0.5997 - accuracy: 0.6928
# Epoch 9/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5983 - accuracy: 0.6947
# Epoch 10/20
# 401/401 [==============================] - 0s 919us/step - loss: 0.5968 - accuracy: 0.6946
# Epoch 11/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5958 - accuracy: 0.6947
# Epoch 12/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5940 - accuracy: 0.6971
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5931 - accuracy: 0.6995
# Epoch 14/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5926 - accuracy: 0.7005
# Epoch 15/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5908 - accuracy: 0.7030
# Epoch 16/20
# 401/401 [==============================] - 0s 932us/step - loss: 0.5904 - accuracy: 0.7025
# Epoch 17/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5901 - accuracy: 0.7049
# Epoch 18/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.5893 - accuracy: 0.7033
# Epoch 19/20
# 401/401 [==============================] - 2s 6ms/step - loss: 0.5882 - accuracy: 0.7039
# Epoch 20/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.5882 - accuracy: 0.7046
# 134/134 - 0s - loss: 0.5777 - accuracy: 0.7070
# 841
# Epoch 1/20
# 401/401 [==============================] - 2s 3ms/step - loss: 0.6600 - accuracy: 0.6175
# Epoch 2/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.6120 - accuracy: 0.6889
# Epoch 3/20
# 401/401 [==============================] - 2s 4ms/step - loss: 0.6067 - accuracy: 0.6906
# Epoch 4/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.6058 - accuracy: 0.6932
# Epoch 5/20
# 401/401 [==============================] - 1s 3ms/step - loss: 0.6049 - accuracy: 0.6929
# Epoch 6/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.6020 - accuracy: 0.6920
# Epoch 7/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.6914
# Epoch 8/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5992 - accuracy: 0.6934
# Epoch 9/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5985 - accuracy: 0.6931
# Epoch 10/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5961 - accuracy: 0.6942
# Epoch 11/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.5953 - accuracy: 0.6945
# Epoch 12/20
# 401/401 [==============================] - 0s 961us/step - loss: 0.5947 - accuracy: 0.6953
# Epoch 13/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5933 - accuracy: 0.6964
# Epoch 14/20
# 401/401 [==============================] - 0s 900us/step - loss: 0.5924 - accuracy: 0.6979
# Epoch 15/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5910 - accuracy: 0.7006
# Epoch 16/20
# 401/401 [==============================] - 0s 903us/step - loss: 0.5898 - accuracy: 0.7021
# Epoch 17/20
# 401/401 [==============================] - 0s 889us/step - loss: 0.5895 - accuracy: 0.7014
# Epoch 18/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.5887 - accuracy: 0.7005
# Epoch 19/20
# 401/401 [==============================] - 0s 869us/step - loss: 0.5883 - accuracy: 0.7038
# Epoch 20/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.5874 - accuracy: 0.7036
# 134/134 - 1s - loss: 0.5795 - accuracy: 0.7091
# 842
# Epoch 1/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6885 - accuracy: 0.5390
# Epoch 2/20
# 401/401 [==============================] - 0s 1ms/step - loss: 0.6229 - accuracy: 0.6809
# Epoch 3/20
# 401/401 [==============================] - 1s 1ms/step - loss: 0.6066 - accuracy: 0.6945
# Epoch 4/20
# 401/401 [==============================] - 1s 2ms/step - loss: 0.6033 - accuracy: 0.6924
# Epoch 5/20
# 138/401 [=========>....................] - ETA: 0s - loss: 0.6007 - accuracy: 0.6981

# %%
print(data)
with open ('Run_results.csv', 'a', encoding='utf-8', newline='') as f:
      writer = csv.writer(f) #this is the writer object
      # writer.writerow(column_name) # this will list out the names of the columns which are always the first entrries
      writer.writerow(data) #this is the data
f.close()
# Out:
# [0.7131166458129883, 0.5822547674179077, 2, 25, 124, 20, 0, 0, 0, 0, 'relu', 'relu', 'sigmoid', 'relu', 0, 0, 'sigmoid']

# %%
Stop Here
# Out:
#   Cell In[45], line 1
#     Stop Here
#          ^
# SyntaxError: invalid syntax

# %%
# Evaluate the model using the test data

# Create a DataFrame containing training history
history_df = pd.DataFrame(fit_model.history)

# Increase the index by 1 to match the number of epochs
history_df.index += 1

# Plot the loss
history_df.plot(y="loss", xlabel='Ecoch', ylabel='Loss', title='Loss')                          # ylim = (0,1)
history_df.plot(y="accuracy", xlabel='Ecoch', ylabel='Accuracy [%]', title='Accuracy')          # ylim = (0,1)

model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
# Export our model to HDF5 file
#  YOUR CODE GOES HERE

now = datetime.now()
acc = str(int(model_accuracy*10000))
filename = now.strftime("%Y-%m-%d-%H%M%S-")+acc+"-weights.hdf5"
nn.save_weights(filename)

# Save the entire model to a HDF5 file.
# The '.h5' extension indicates that the model should be saved to HDF5.
filename = now.strftime("%Y-%m-%d-%H%M%S-")+acc+"-model.h5"
nn.save(filename)

# %% [markdown]
# ---
# ### Optimize the Model (Step 3)
#
# Using your knowledge of TensorFlow, optimize your model to achieve a target predictive accuracy higher than 75%.
#
# Using any or all of the following methods to optimize your model:
#
# * Adjust the input data to ensure that no variables or outliers are causing confusion in the model, such as:
#   * Dropping more or fewer columns.
#   * Creating more bins for rare occurrences in columns.
#   * Increasing or decreasing the number of values for each bin.
# * Add more neurons to a hidden layer.
# * Add more hidden layers.
# * Use different activation functions for the hidden layers.
# * Add or reduce the number of epochs to the training regimen.
#
# **Note**: If you make at least three attempts at optimizing your model, you will not lose points if your model does not achieve target performance.
#
# 1. Create a new Jupyter Notebook file and name it `AlphabetSoupCharity_Optimzation.ipynb`.
#
# 2. Import your dependencies and read in the `charity_data.csv` to a Pandas DataFrame.
#
# 3. Preprocess the dataset like you did in Step 1, Be sure to adjust for any modifications that came out of optimizing the model.
#
# 4. Design a neural network model, and be sure to adjust for modifications that will optimize the model to achieve higher than 75% accuracy.
#
# 5. Save and export your results to an HDF5 file. Name the file `AlphabetSoupCharity_Optimization.h5`.

# %% [markdown]
# ---
# ### Step 4: Write a Report on the Neural Network Model
#
# For this part of the assignment, you’ll write a report on the performance of the deep learning model you created for AlphabetSoup.
#
# The report should contain the following:
#
# 1. **Overview** of the analysis: Explain the purpose of this analysis.
#
# 2. **Results**: Using bulleted lists and images to support your answers, address the following questions.
#
#   * Data Preprocessing
#     * What variable(s) are the target(s) for your model?
#     * What variable(s) are the features for your model?
#     * What variable(s) should be removed from the input data because they are neither targets nor features?
#
# * Compiling, Training, and Evaluating the Model
#     * How many neurons, layers, and activation functions did you select for your neural network model, and why?
#     * Were you able to achieve the target model performance?
#     * What steps did you take in your attempts to increase model performance?
#
# 3. **Summary**: Summarize the overall results of the deep learning model. Include a recommendation for how a different model could solve this classification problem, and then explain your recommendation.
